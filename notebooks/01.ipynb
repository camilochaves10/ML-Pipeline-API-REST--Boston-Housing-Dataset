# %%
import pandas as pd
import numpy as np
import os

# %%
os.getcwd()

# %%
df = pd.read_csv('../data/HousingData.csv')

# %%
df.head()

# %%
df.shape
df.describe()
df.info()
df.isnull().sum()
df.isnull().sum()/len(df)
df.isnull().sum()/len(df)
